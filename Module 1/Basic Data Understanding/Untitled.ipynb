# %% [markdown]
# ### Plotting Mathematical Functions

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
from matplotlib import pyplot as plt
from math import pi

# %%
x = np.arange(-pi,pi,0.1)
y = np.sin(x)
plt.plot(x,y,'ro') #other values include 'ro','bo','r',etc
plt.plot(x,np.cos(x))
plt.xlabel('pi')
plt.ylabel('sin(x) and cos(x)')
plt.legend(['sin','cos'])
plt.show()

# %% [markdown]
# ### Plotting Line Plots

# %%
x = [1,2,3]
y = [1,4,9]
z = [10,5,0]
plt.plot(x,y)
plt.plot(x,z)
plt.xlabel('x')
plt.ylabel('y and z')
plt.legend(['y','z'])
plt.show()

# %% [markdown]
# ### Visualizing Data

# %%
sample_data = pd.read_csv('sample_data.csv')
sample_data
# Out:
#    column_a  column_b  column_c
# 0         1         1        10
# 1         2         4         8
# 2         3         9         6
# 3         4        16         4
# 4         5        25         2

# %%
type(sample_data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(sample_data.column_c)
# Out:
# pandas.core.series.Series

# %%
sample_data.column_c.iloc[0]
# Out:
# 10

# %%
plt.plot(sample_data.column_a, sample_data.column_b)
plt.plot(sample_data.column_a, sample_data.column_c)
plt.legend(['column_b','column_c'])
plt.xlabel('column_a')
plt.show()

# %%
data = pd.read_csv('countries.csv')
data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
# Comparing the population growth in the US and China
us = data[data.country == 'United States']
china = data[data.country == 'China']

# %%
plt.plot(us.year, us.population )
plt.plot(china.year, china.population)
plt.legend(['US', 'CHINA'])
plt.xlabel('Year')
plt.ylabel('Population')
plt.show()

# %%
movies = pd.read_csv('moviesData.csv')
movies.head()
# Out:
#    Unnamed: 0                 title    title_type   genre  runtime  \
# 0           1           Filly Brown  Feature Film   Drama     80.0
# 1           2              The Dish  Feature Film   Drama    101.0
# 2           3   Waiting for Guffman  Feature Film  Comedy     84.0
# 3           4  The Age of Innocence  Feature Film   Drama    139.0
# 4           5           Malevolence  Feature Film  Horror     90.0
#
#   mpaa_rating                    studio  thtr_rel_year  thtr_rel_month  \
# 0           R       Indomina Media Inc.           2013               4
# 1       PG-13     Warner Bros. Pictures           2001               3
# 2           R    Sony Pictures Classics           1996               8
# 3          PG         Columbia Pictures           1993              10
# 4           R  Anchor Bay Entertainment           2004               9
#
#    thtr_rel_day  ...  best_actor_win  best_actress_win  best_dir_win  \
# 0            19  ...              no                no            no
# 1            14  ...              no                no            no
# 2            21  ...              no                no            no
# 3             1  ...             yes                no           yes
# 4            10  ...              no                no            no
#
#    top200_box           director             actor1              actor2  \
# 0          no   Michael D. Olmos     Gina Rodriguez        Jenni Rivera
# 1          no          Rob Sitch          Sam Neill    Kevin Harrington
# 2          no  Christopher Guest  Christopher Guest    Catherine O'Hara
# 3          no    Martin Scorsese   Daniel Day-Lewis   Michelle Pfeiffer
# 4          no        Stevan Mena      Samantha Dark  R. Brandon Johnson
#
#                  actor3            actor4               actor5
# 0  Lou Diamond Phillips     Emilio Rivera  Joseph Julian Soria
# 1     Patrick Warburton          Tom Long       Genevieve Mooy
# 2          Parker Posey       Eugene Levy          Bob Balaban
# 3          Winona Ryder  Richard E. Grant         Alec McCowen
# 4       Brandon Johnson     Heather Magee       Richard Glover
#
# [5 rows x 31 columns]

# %%
movies.shape
# Out:
# (600, 31)

# %%
plt.hist(movies.runtime)
# Out:
# (array([  2.,  35., 329., 179.,  40.,   8.,   4.,   1.,   0.,   1.]),
#  array([ 39. ,  61.8,  84.6, 107.4, 130.2, 153. , 175.8, 198.6, 221.4,
#         244.2, 267. ]),
#  <BarContainer object of 10 artists>)

# %%
movies.runtime.describe()
# Out:
# count    599.000000
# mean     105.884808
# std       19.542042
# min       39.000000
# 25%       93.000000
# 50%      102.000000
# 75%      115.000000
# max      267.000000
# Name: runtime, dtype: float64

# %%
movies.runtime.isna().sum()
# Out:
# 1

# %%
movies = movies.dropna()

# %%
movies.runtime.isna().sum()
# Out:
# 0

# %%
plt.hist(movies.runtime, bins = 7, color = 'green', orientation = 'vertical')
plt.title("Distribution of movies' length")
plt.xlabel('Runtime of movies')
plt.xlim(0,300)
# Out:
# (0.0, 300.0)

# %%
genre = movies.genre.value_counts()
genre
# Out:
# genre
# Drama                        298
# Comedy                        86
# Action & Adventure            62
# Mystery & Suspense            56
# Documentary                   40
# Horror                        22
# Science Fiction & Fantasy      8
# Name: count, dtype: int64

# %%
plt.pie(genre, labels = genre.i)
# Out:
# ([<matplotlib.patches.Wedge at 0x24a83a5acd0>,
#   <matplotlib.patches.Wedge at 0x24a86e3a810>,
#   <matplotlib.patches.Wedge at 0x24a86e21210>,
#   <matplotlib.patches.Wedge at 0x24a86e20890>,
#   <matplotlib.patches.Wedge at 0x24a86e22d10>,
#   <matplotlib.patches.Wedge at 0x24a86e22b90>,
#   <matplotlib.patches.Wedge at 0x24a835bee10>],
#  [Text(-0.07244590612571755, 1.0976117668308882, '298'),
#   Text(-0.9052821579754745, -0.6248713583220695, '86'),
#   Text(-0.16849655599046048, -1.0870183579955557, '62'),
#   Text(0.5218635555617395, -0.9683276456739524, '56'),
#   Text(0.9382197721008766, -0.5742331053143656, '40'),
#   Text(1.0761295786314555, -0.2279147428195161, '22'),
#   Text(1.0989383578391803, -0.04831651549652366, '8')])
